# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramisrkit/CodeAlpha_Unemployment-Analysis-With-Python/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv("/content/Unemployment in India.csv")
print(d.to_string())
# Out:
#                Region         Date  Frequency   Estimated Unemployment Rate (%)   Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0      Andhra Pradesh   31-05-2019    Monthly                              3.65           11999139.0                                     43.24  Rural
# 1      Andhra Pradesh   30-06-2019    Monthly                              3.05           11755881.0                                     42.05  Rural
# 2      Andhra Pradesh   31-07-2019    Monthly                              3.75           12086707.0                                     43.50  Rural
# 3      Andhra Pradesh   31-08-2019    Monthly                              3.32           12285693.0                                     43.97  Rural
# 4      Andhra Pradesh   30-09-2019    Monthly                              5.17           12256762.0                                     44.68  Rural
# ...

# %%
print(d.dtypes)
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                         float64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object
# dtype: object

# %%
d.columns=[i.strip() for i in d.columns]

# %%
d["Date"]=pd.to_datetime(d["Date"],errors="coerce",dayfirst=True)

# %%
d
# Out:
#              Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1    Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2    Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3    Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4    Andhra Pradesh 2019-09-30   Monthly                             5.17
# ..              ...        ...       ...                              ...
# 763             NaN        NaT       NaN                              NaN
# 764             NaN        NaT       NaN                              NaN
# 765             NaN        NaT       NaN                              NaN
# 766             NaN        NaT       NaN                              NaN
# 767             NaN        NaT       NaN                              NaN
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# ...

# %%
d.dropna(inplace=True)

# %%
d
# Out:
#              Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1    Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2    Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3    Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4    Andhra Pradesh 2019-09-30   Monthly                             5.17
# ..              ...        ...       ...                              ...
# 749     West Bengal 2020-02-29   Monthly                             7.55
# 750     West Bengal 2020-03-31   Monthly                             6.67
# 751     West Bengal 2020-04-30   Monthly                            15.63
# 752     West Bengal 2020-05-31   Monthly                            15.22
# 753     West Bengal 2020-06-30   Monthly                             9.86
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# ...

# %%
s = d.groupby(d["Date"].dt.month)["Estimated Unemployment Rate (%)"].mean().reset_index()
s.columns = ["Month", "Estimated Unemployment Rate (%)"]
plt.figure(figsize=(10,10))
sns.lineplot(x="Month",y="Estimated Unemployment Rate (%)",data=s,marker="o")
plt.xticks(s["Month"], s["Month"].astype(str))
plt.show()

# %%
s = d.groupby(d["Date"].dt.year)["Estimated Unemployment Rate (%)"].mean().reset_index()
s.columns = ["Year", "Estimated Unemployment Rate (%)"]
plt.figure(figsize=(10,10))
sns.lineplot(x="Year",y="Estimated Unemployment Rate (%)",data=s,marker="o")
plt.xticks(s["Year"], s["Year"].astype(str))
plt.show()

# %%
s = d.groupby(d["Date"])["Estimated Unemployment Rate (%)"].mean().reset_index()
s.columns = ["Date", "Estimated Unemployment Rate (%)"]
plt.figure(figsize=(15,10))
sns.lineplot(x="Date",y="Estimated Unemployment Rate (%)",data=s,marker="o")
plt.xticks(s["Date"])
plt.show()

# %%
plt.figure(figsize=(44,10))
sns.barplot(x="Region",y="Estimated Unemployment Rate (%)",data=d)
plt.xticks(d["Region"],fontsize=9)
plt.show()

# %%
s = d.groupby(d["Date"].dt.year)["Estimated Unemployment Rate (%)"].mean().reset_index()
s.columns = ["Year", "Estimated Unemployment Rate (%)"]
sns.barplot(x="Year",y="Estimated Unemployment Rate (%)",data=s)
plt.show()

# %%
plt.figure(figsize=(43,10))
sns.boxplot(x="Region",y="Estimated Unemployment Rate (%)",data=d)
plt.show()

# %%
d["Month"]= d["Date"].dt.month
plt.figure(figsize=(12,6))
sns.boxplot(x="Month",y="Estimated Unemployment Rate (%)",data=d)
plt.show()

# %%
print(d.dtypes)
# Out:
# Region                                             object
# Date                                       datetime64[ns]
# Frequency                                          object
# Estimated Unemployment Rate (%)                   float64
# Estimated Employed                                float64
# Estimated Labour Participation Rate (%)           float64
# Area                                               object
# Month                                               int32
# dtype: object

# %%
d['year']=d['Date'].dt.year
pivot = d.pivot_table(values="Estimated Labour Participation Rate (%)", index='year', columns='Month', aggfunc='mean')
sns.heatmap(pivot, cmap='viridis', annot=True,annot_kws={"color":"black"})
plt.show()
